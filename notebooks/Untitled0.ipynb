# %% [markdown]
# <a href="https://colab.research.google.com/github/abangalore/Colab-Test/blob/main/notebooks/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
with open('/content/gdrive/My Drive/all_model_data-2022-06-20.csv', 'r') as f:
    print(f.read())
# Out:
# "target","target_end_date","forecast_date","model","location_name","quantile_0.025","quantile_0.25","quantile_0.5","quantile_0.75","quantile_0.975"
# "1 wk ahead inc flu hosp",2022-06-25,2022-06-20,"FluSight-Ensemble","Alabama",7,13,17,20,27
# "1 wk ahead inc flu hosp",2022-06-25,2022-06-20,"FluSight-Ensemble","Alaska",0,0,2,4,8
# "1 wk ahead inc flu hosp",2022-06-25,2022-06-20,"FluSight-Ensemble","Arizona",21,39,50,68,92
# "1 wk ahead inc flu hosp",2022-06-25,2022-06-20,"FluSight-Ensemble","Arkansas",3,8,12,16,23
# "1 wk ahead inc flu hosp",2022-06-25,2022-06-20,"FluSight-Ensemble","California",191,255,290,321,378
# "1 wk ahead inc flu hosp",2022-06-25,2022-06-20,"FluSight-Ensemble","Colorado",6,17,24,33,52
# "1 wk ahead inc flu hosp",2022-06-25,2022-06-20,"FluSight-Ensemble","Connecticut",4,10,14,20,29
# "1 wk ahead inc flu hosp",2022-06-25,2022-06-20,"FluSight-Ensemble","Delaware",0,1,3,5,9
# ...

# %%
from google.colab import files

uploaded = files.upload()

for filename in uploaded.keys():
    print(uploaded[filename])
# Out:
#      <input type="file" id="files-ecf2561e-cb2b-4f63-b0be-af1ad0209c12" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ecf2561e-cb2b-4f63-b0be-af1ad0209c12">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !wget 25.io/toau/audio/sample.txt
# Out:
# --2022-11-02 16:48:51--  http://25.io/toau/audio/sample.txt
# Resolving 25.io (25.io)... 192.169.145.195
# Connecting to 25.io (25.io)|192.169.145.195|:80... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2022-11-02 16:48:51 ERROR 404: Not Found.
